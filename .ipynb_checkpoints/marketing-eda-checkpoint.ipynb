# %% [markdown]
# ## Importing Libraries

# %%
# !pip install ucimlrepo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Dataset

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222) 
  
# data (as pandas dataframes) 
X = bank_marketing.data.features 
y = bank_marketing.data.targets 
  
# metadata 
print(bank_marketing.metadata) 
  
# variable information 
print(bank_marketing.variables)
# Out:
# {'uci_id': 222, 'name': 'Bank Marketing', 'repository_url': 'https://archive.ics.uci.edu/dataset/222/bank+marketing', 'data_url': 'https://archive.ics.uci.edu/static/public/222/data.csv', 'abstract': 'The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).', 'area': 'Business', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 45211, 'num_features': 16, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Occupation', 'Marital Status', 'Education Level'], 'target_col': ['y'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2014, 'last_updated': 'Fri Aug 18 2023', 'dataset_doi': '10.24432/C5K306', 'creators': ['S. Moro', 'P. Rita', 'P. Cortez'], 'intro_paper': {'ID': 277, 'type': 'NATIVE', 'title': 'A data-driven approach to predict the
# ...

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ![image.png](attachment:f5d15f50-c710-49c7-8692-a483f63369ce.png)

# %% [markdown]
# ## Data Cleaning

# %%
X.isnull().sum()
# Out:
# age                0
# job              288
# marital            0
# education       1857
# default            0
# balance            0
# housing            0
# loan               0
# contact        13020
# day_of_week        0
# month              0
# duration           0
# campaign           0
# pdays              0
# previous           0
# poutcome       36959
# dtype: int64

# %%
X['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# Name: count, dtype: int64

# %%
X.loc[:,'job']=X['job'].fillna('blue-collar')

# %%
X['education'].value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# Name: count, dtype: int64

# %%
X.loc[:,'education']=X['education'].fillna('secondary')

# %%
X['contact'].value_counts()
# Out:
# contact
# cellular     29285
# telephone     2906
# Name: count, dtype: int64

# %%
X.loc[:,'contact']=X['contact'].fillna('secondary')

# %%
X['poutcome'].value_counts()
# Out:
# poutcome
# failure    4901
# other      1840
# success    1511
# Name: count, dtype: int64

# %%
X.loc[:,'poutcome']=X['poutcome'].fillna('failure')

# %%
X.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# contact        0
# day_of_week    0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# dtype: int64

# %%
X.isna().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# contact        0
# day_of_week    0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# dtype: int64

# %%
X.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
X['Outcome']=y

# %%
numeric=['age', 'balance', 'duration', 'campaign','pdays', 'previous']
for i in numeric:
    plt.figure(figsize=(8,5))
    plt.subplot(1,2,1)
    X[ X['Outcome'] == 'yes'][i].plot(kind='box',colormap='viridis')
    plt.xlabel(f'{i} for yes')
    plt.ylabel('Distribution')
    
    plt.subplot(1,2,2)
    X[ X['Outcome'] == 'no'][i].plot(kind='box')
    plt.xlabel(f'{i} for no')
    plt.ylabel('Distribution')
    plt.show()

# %%
categorical=['job', 'marital', 'education', 'default', 'housing',
       'loan', 'contact','poutcome']

for i in categorical:
    plt.figure(figsize=(8,5))
    plt.subplot(1,2,1)
    X[ X['Outcome'] == 'yes'][i].value_counts().plot(kind='bar',colormap='viridis')
    plt.xlabel(f'{i}-type for yes')
    plt.ylabel('Counts')
    
    plt.subplot(1,2,2)
    X[ X['Outcome'] == 'no'][i].value_counts().plot(kind='bar')
    plt.xlabel(f'{i}-type for no')
    plt.ylabel('Counts')
    plt.show()

# %%
y.value_counts().plot(kind='pie',autopct='%1.1f')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
mapping_dict = {'no':0, 'yes': 1}
X.loc[:,'Outcome']=X['Outcome'].map(mapping_dict)

# %%
yes_depo=X[ X['Outcome'] == 1]
no_depo=X[ X['Outcome'] == 0]

pd.crosstab(yes_depo['marital'],values=yes_depo['job'],columns=yes_depo['job'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=Yes')

pd.crosstab(no_depo['marital'],values=no_depo['job'],columns=no_depo['job'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=No')
plt.show()

# %%
pd.crosstab(yes_depo['poutcome'],values=yes_depo['loan'],columns=yes_depo['loan'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=Yes')

pd.crosstab(no_depo['poutcome'],values=no_depo['loan'],columns=no_depo['loan'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=No')
plt.show()

# %%
pd.crosstab(yes_depo['contact'],values=yes_depo['job'],columns=yes_depo['job'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=Yes')

pd.crosstab(no_depo['contact'],values=no_depo['job'],columns=no_depo['job'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=No')
plt.show()

# %%
pd.crosstab(yes_depo['housing'],values=yes_depo['default'],columns=yes_depo['default'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=Yes')

pd.crosstab(no_depo['housing'],values=no_depo['default'],columns=no_depo['default'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=No')
plt.show()

# %%
pd.crosstab(yes_depo['loan'],values=yes_depo['default'],columns=yes_depo['default'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=Yes')

pd.crosstab(no_depo['loan'],values=no_depo['default'],columns=no_depo['default'],aggfunc='count',normalize=True).plot(kind='bar')
plt.title('For deposited=No')
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
mapping_dict = {'no':0, 'yes': 1}
X.loc[:,'Outcome']=X['Outcome'].map(mapping_dict)

# %%
sns.pairplot(data=X[['age', 'balance', 'duration', 'campaign','pdays', 'previous','Outcome']],hue='Outcome')

# %%
df_clean=X.drop(columns=['Outcome','day_of_week','month'],axis=1)

# %%
df_clean.to_csv('bank-marketing-cleaned.csv')

# %%
df_clean.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome'],
#       dtype='object')

# %%
y.to_csv('outcome.csv')
